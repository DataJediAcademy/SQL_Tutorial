# %% [markdown]
# # Introduction to SQL

# %% [markdown]
# ### Introduction
# Describe the objective of the notebook and explain how to write scripts in the notebook.
# Describe how to run sql script in the jupyter notebook

# %% [markdown]
# ### Required packages

# %%
import sqlite3
import pandas as pd

# custom database setup script required to run database script
from  database_setup import *

# %% [markdown]
# ### Content
#
# 1. Brief description of SQL
# 2. Description of the Sample Database used in the jupyter notebook
# 3. SQL Commands Overview
# a. Data Manipulaton Language (DML)
# b. Data Definition Language (DDL)
# c. Data Query Language (DQL)
# d. Data Control Language (DCL)
# 4. SQL Query Performance Tuning (Demonstrate the need for performance tuning using %timeit)
# 5. Additional Resources

# %% [markdown]
# sql = 'select * from orders'
# run_sql_script(sql)

# %%
sql = 'select * from Customers'
run_sql_script(sql)
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taquería      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                  Berglunds snabbköp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country
# ...

# %%
sql = '''
        select a.CustomerID, b.CustomerName, count(a.OrderID) as No_Of_Orders  from 
        Orders as a 
        join Customers as b on a.CustomerID = b.CustomerID 
        group by a.CustomerID
        order by No_Of_Orders desc;
      '''


run_sql_script(sql)
# Out:
#     CustomerID                        CustomerName  No_Of_Orders
# 0           20                        Ernst Handel            10
# 1           87                      Wartian Herkku             7
# 2           65          Rattlesnake Canyon Grocery             7
# 3           63                          QUICK-Stop             7
# 4           75               Split Rail Beer & Ale             6
# ..         ...                                 ...           ...
# 69          13          Centro comercial Moctezuma             1
# 70          11                       B's Beverages             1
# 71           8           Bólido Comidas preparadas             1
# 72           3             Antonio Moreno Taquería             1
# 73           2  Ana Trujillo Emparedados y helados             1
#
# [74 rows x 3 columns]
